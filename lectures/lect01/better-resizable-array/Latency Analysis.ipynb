# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
latencies = pd.read_csv("results.csv").set_index("i")
latencies
# Out:
#          double_push  double_get  hat_push  hat_get
# i
# 0                363          27       399      531
# 1                 55          99        74       57
# 2                 28          26        28       28
# 3                 26          27        29       30
# 4                 26          26      8609       26
# ...              ...         ...       ...      ...
# 1048572           24          26        30       26
# 1048573           26          30        27       26
# 1048574           28          26        28       26
# 1048575           26          28        27       27
# 1048576     30378781          26  15530388       26
#
# [1048577 rows x 4 columns]

# %%
fig, ((ax1, ax2)) = plt.subplots(1, 2, figsize=(20, 10))

ax1.plot(latencies["double_push"])
ax2.plot(latencies["hat_push"])
